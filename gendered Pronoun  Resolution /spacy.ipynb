# %% [markdown]
# <a id="11"></a> <br>
# ##   1-1 Import

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib
import warnings
import sklearn
import gensim
import scipy
import numpy
import json
import nltk
import sys
import csv
import os

# %% [markdown]
# <a id="12"></a> <br>
# ## 1-2 Version

# %%
print('matplotlib: {}'.format(matplotlib.__version__))
print('scipy: {}'.format(scipy.__version__))
print('seaborn: {}'.format(sns.__version__))
print('pandas: {}'.format(pd.__version__))
print('numpy: {}'.format(np.__version__))
print('Python: {}'.format(sys.version))
# Out:
# matplotlib: 3.0.3
# scipy: 1.1.0
# seaborn: 0.9.0
# pandas: 0.23.4
# numpy: 1.16.2
# Python: 3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16)
# [GCC 7.3.0]

# %% [markdown]
# <a id="13"></a> <br>
# ## 1-3 Setup
#
# A few tiny adjustments for better **code readability**

# %%
sns.set(style='white', context='notebook', palette='deep')
warnings.filterwarnings('ignore')
sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# <a id="14"></a> <br>
# ## 1-4 Data set

# %%
print(os.listdir("../input/"))
# Out:
# ['gendered-pronoun-resolution', 'gapdevelopment']

# %%
# @inproceedings{webster2018gap,
#   title =     {Mind the GAP: A Balanced Corpus of Gendered Ambiguou},
#   author =    {Webster, Kellie and Recasens, Marta and Axelrod, Vera and Baldridge, Jason},
#   booktitle = {Transactions of the ACL},
#   year =      {2018},
#   pages =     {to appear}
# }

# %%
gendered_pronoun_df = pd.read_csv('../input/gapdevelopment/gap-development.tsv', delimiter='\t')
test_df1 = pd.read_csv('../input/gendered-pronoun-resolution/test_stage_1.tsv', delimiter='\t')
test_df2 = pd.read_csv('../input/gendered-pronoun-resolution/test_stage_2.tsv', delimiter='\t')

# %%
submission1 = pd.read_csv('../input/gendered-pronoun-resolution/sample_submission_stage_1.csv')
submission2 = pd.read_csv('../input/gendered-pronoun-resolution/sample_submission_stage_2.csv')

# %%
gendered_pronoun_df.shape
# Out:
# (2000, 11)

# %%
test_df2.shape
# Out:
# (12359, 9)

# %%
submission2.shape
# Out:
# (12359, 4)

# %% [markdown]
# <a id="15"></a> <br>
# ## 1-5 Gendered Pronoun Data set Analysis
# <img src='https://storage.googleapis.com/kaggle-media/competitions/GoogleAI-GenderedPronoun/PronounResolution.png' width=600 height=600>
# **Pronoun resolution** is part of coreference resolution, the task of pairing an expression to its referring entity. This is an important task for natural language understanding, and the resolution of ambiguous pronouns is a longstanding challenge. for more information you can check this [link](https://www.kaggle.com/c/gendered-pronoun-resolution)
# <a id="151"></a> <br>
# ### 1-5-1 Problem Feature
# In this competition, you must identify the target of a pronoun within a text passage. The source text is taken from Wikipedia articles. You are provided with the pronoun and two candidate names to which the pronoun could refer. You must create an algorithm capable of deciding whether the pronoun refers to name A, name B, or neither.

# %%
gendered_pronoun_df.head()
# Out:
#               ID                        ...                                                                        URL
# 0  development-1                        ...                          http://en.wikipedia.org/wiki/List_of_Teachers_...
# 1  development-2                        ...                              http://en.wikipedia.org/wiki/Warren_MacKenzie
# 2  development-3                        ...                          http://en.wikipedia.org/wiki/Jos%C3%A9_Manuel_...
# 3  development-4                        ...                                  http://en.wikipedia.org/wiki/Crime_(band)
# 4  development-5                        ...                                http://en.wikipedia.org/wiki/Jessica_Rivera
#
# [5 rows x 11 columns]

# %%
test_df2.head()
# Out:
#                                  ID                        ...                                                                        URL
# 0  000075809a8e6b062f5fb3c191a8ed52                        ...                                   http://en.wikipedia.org/wiki/Lucy_Benson
# 1  0005d0f3b0a6c9ffbd31a48453029911                        ...                             http://en.wikipedia.org/wiki/Alla_Kudryavtseva
# 2  0007775c40bedd4147a0573d66dc28f8                        ...                          http://en.wikipedia.org/wiki/Development_of_th...
# 3  001194e3fe1234d00198ef6bba4cc588                        ...                                  http://en.wikipedia.org/wiki/Dian_Alberts
# 4  0014bb7085278ef3f9b74f14771caca9                        ...                           http://en.wikipedia.org/wiki/Madame_de_Pompadour
#
# [5 rows x 9 columns]

# %%
gendered_pronoun_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
# ID                2000 non-null object
# Text              2000 non-null object
# Pronoun           2000 non-null object
# Pronoun-offset    2000 non-null int64
# A                 2000 non-null object
# A-offset          2000 non-null int64
# A-coref           2000 non-null bool
# B                 2000 non-null object
# B-offset          2000 non-null int64
# B-coref           2000 non-null bool
# URL               2000 non-null object
# dtypes: bool(2), int64(3), object(6)
# memory usage: 144.6+ KB

# %% [markdown]
# <a id="152"></a> <br>
# ### 1-5-2  Variables
#
# 1. ID - Unique identifier for an example (Matches to Id in output file format)
# 1. Text - Text containing the ambiguous pronoun and two candidate names (about a paragraph in length)
# 1. Pronoun - The target pronoun (text)
# 1. Pronoun-offset The character offset of Pronoun in Text
# 1. A - The first name candidate (text)
# 1. A-offset - The character offset of name A in Text
# 1. B - The second name candidate
# 1. B-offset - The character offset of name B in Text
# 1. URL - The URL of the source Wikipedia page for the example

# %% [markdown]
# <a id="153"></a> <br>
# ### 1-5-3  Evaluation
# Submissions are evaluated using the multi-class logarithmic loss. Each pronoun has been labeled with whether it refers to A, B, or NEITHER. For each pronoun, you must submit a set of predicted probabilities (one for each class). The formula is :
# <img src='http://s8.picofile.com/file/8351608076/1.png'>

# %% [markdown]
# <a id="3"></a> <br>
# ## spaCy
# spaCy is an Industrial-Strength Natural Language Processing in python. [**spacy**](https://spacy.io/)

# %%
import spacy

# %%
nlp = spacy.load('en')
def doc(row):
    return nlp(row['Text'])

# %%
gendered_pronoun_df['doc'] = gendered_pronoun_df.apply(doc,axis=1)

# %%
test_df2['doc'] = test_df2.apply(doc,axis=1)

# %%
sample= gendered_pronoun_df.loc[0]
# extract the sentence number
for d in sample.doc.sents:
    print(d)
# Out:
# Zoe Telford -- played the police officer girlfriend of Simon, Maggie.
# Dumped by Simon in the final episode of series 1, after he slept with Jenny, and is not seen again.
# Phoebe Thomas played Cheryl Cassidy, Pauline's friend and also a year 11 pupil in Simon's class.
# Dumped her boyfriend following Simon's advice after he wouldn't have sex with her but later realised this was due to him catching crabs off her friend Pauline.

# %%
# extract the dependence 
from spacy import displacy
doc = nlp(sample.Text)
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
depth=''
for d in d.doc:
    d_heads = [_ for _ in d.ancestors]
    depth+=d.text+'('+str(len(d_heads))+') '
print(depth)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="572d0bbc3756461fa56750bc8c90210c-0" class="displacy" width="6980" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Zoe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Telford --</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">played</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">police</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">officer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">girlfriend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Simon,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">Maggie.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Dumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Simon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">final</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">episode</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">series</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">1,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">slept</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Jenny,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">seen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">again.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Phoebe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text
# Zoe(2) Telford(1) --(2) played(0) the(2) police(3) officer(2) girlfriend(1) of(2) Simon(3) ,(4) Maggie(4) .(1) Dumped(0) by(1) Simon(2) in(1) the(3) final(3) episode(2) of(3) series(4) 1(5) ,(1) after(2) he(2) slept(1) with(2) Jenny(3) ,(2) and(2) is(3) not(3) seen(2) again(3) .(1) Phoebe(2) Thomas(1) played(0) Cheryl(2) Cassidy(1) ,(2) Pauline(3) 's(4) friend(2) and(3) also(3) a(4) year(3) 11(4) pupil(2) in(3) Simon(5) 's(6) class(4) .(1) Dumped(0) her(2) boyfriend(1) following(1) Simon(3) 's(4) advice(2) after(2) he(2) would(2) n't(2) have(1) sex(2) with(2) her(3) but(2) later(3) realised(2) this(4) was(3) due(4) to(5) him(6) catching(5) crabs(6) off(6) her(8) friend(7) Pauline(8) .(1)

# %%
def offset_to_index(row,col):
    stop = row[col+'-offset']+len(row[col])
    length = len(row['doc'])
    for i in range(length):
        if len(row['doc'][:i+1].text) >= stop:
            #print(row['doc'][i-1])
            return i  
        
def sentence_number(row,col):
    i=0
    count=0
    for d in row.doc.sents:
        count+=len(d)
        i+=1
        if count>= row[col+'-index']:
            return i

def ancestors(row,col):
    d = row['doc'][int(row[col+'-index'])]
    d_heads = [_ for _ in d.ancestors]
    if d_heads:
        ancestor=d_heads[-1].text
    else:
        ancestor='Null'
    #print(len(d_heads),ancestor,d.dep_)
    return pd.Series([len(d_heads),ancestor,d.dep_])

# %%
def data_process(df):
    for col in ['Pronoun','A','B']:
        df[col+'-index'] = df.apply(offset_to_index,col=col,axis=1)
        df[col+'-sent'] = df.apply(sentence_number,col=col,axis=1)
        df[[col+'-depth',col+'-ancestor', col+'-dep']] = df.apply(ancestors, col=col, axis=1)
        #creat some features from the dependencies
        if col in ['A','B']:
            df[col+'-sentdistance'] = df['Pronoun-sent']-df[col+'-sent']
            df[col+'-depthdistance'] = df['Pronoun-depth']-df[col+'-depth']
            df[col+'-sameancestor'] = (df['Pronoun-ancestor']==df[col+'-ancestor'])*1
            df[col+'-samedep'] = (df['Pronoun-dep']==df[col+'-dep'])*1

# %%
data_process(gendered_pronoun_df)

# %%
data_process(test_df2)

# %%
#check if all the name-indexes are right
def consistant(df):
    badlist=[]
    for row_index,row in df.iterrows():
        for col in ['A','B','Pronoun']:
            #print(row[col].split()[-1],row['doc'][int(row[col+'-index'])])
            if row[col].split()[-1]!=row['doc'][int(row[col+'-index'])].text:
                print(col,'---',row[col],'---',row['doc'][row[col+'-index']])
                badlist+=[row_index]
        
    return badlist

# %%
print(consistant(gendered_pronoun_df))
# Out:
# B --- Bo-lung --- lung
# B --- Adele Chatfield-Taylor --- Taylor
# B --- Gloria Macapagal-Arroyo --- Arroyo
# A --- Gagnon-Tremblay --- Tremblay
# B --- Monique Jerome-Forget --- Forget
# B --- Graeme Dott. --- .
# A --- Paul Pellisson.Il --- Il
# B --- Adie (** --- *
# B --- Delia --- Delia-
# B --- Sarah Fitz-Gerald --- Gerald
# A --- Helen Sainton-Dolby --- Dolby
# A --- Nancy Banks-Smith --- Smith
# B --- 7th Dan Shito-Ryu Karate-Do Sosei-Kai --- Kai
# B --- William P --- P.
# A --- G-Man --- Man
# B --- St*phane Mallarm* --- *
# A --- Jay-Z --- Z
# A --- Betty Thatcher-Newsinger --- Newsinger
# A --- Beyonc* --- *
# A --- Co Stomp* --- Stomp*.
# B --- TV-presenter --- presenter
# A --- Jazmine James --- James-
# B --- Mrs --- Mrs.
# B --- Richard Rainshaw Rothwell I --- I.
# B --- Johnson Aguiyi-Ironsi --- Ironsi
# B --- Lepist* --- *
# A --- Al-Kind* --- *
# B --- Ibn S*n* --- *
# A --- Tatjana Juri* --- *
# A --- Luis Moreno-Ocampo --- Ocampo
# B --- Arch Hall, Sr. --- .
# B --- Herv* --- *
# B --- Bront* --- *
# B --- Jason Aldean --- Aldean(who
# B --- Mrs --- Mrs.
# B --- Ivan *argo --- argo
# B --- Nathan-Turner --- Turner
# B --- Goldman-Simpson --- Simpson
# A --- Charlotte Bront* --- *
# A --- Edward VIII. --- .
# B --- Yemeni-American --- American
# A --- Kimberly --- Kimberly''--were
# A --- Joanne Whalley-Kilmer --- Kilmer
# B --- *af**ov* --- *
# B --- Gloria Macapagal-Arroyo --- Arroyo
# A --- Kralji* --- *
# B --- Daniela Hantuchov* --- *
# B --- Martha Wayles Jefferson. --- .
# B --- Deborah L. ``Debi --- Debi
# B --- Frimpong-Manso --- Manso
# B --- Zhanna Pintusevich-Block --- Block
# B --- Camille Bacon-Smith --- Smith
# B --- Petra Kvitov* --- *
# A --- Karen Clark-Sheard --- Sheard
# B --- Dorinda Clark-Cole --- Cole
# [50, 56, 77, 100, 100, 180, 229, 246, 291, 363, 402, 425, 433, 437, 463, 487, 522, 526, 564, 626, 630, 772, 786, 853, 888, 896, 945, 945, 951, 1069, 1106, 1197, 1209, 1283, 1288, 1298, 1314, 1322, 1391, 1421, 1500, 1548, 1574, 1608, 1627, 1639, 1661, 1670, 1715, 1717, 1740, 1797, 1910, 1911, 1911]

# %%
print(consistant(test_df2))
# Out:
# B --- Margaret Oneill-Prott --- Prott
# B --- James Curtis Skakel Sr. --- .
# B --- Frank Lloyd Wright Jr --- Jr.
# A --- Golding-Kirk --- Kirk
# B --- Natalia Cordova-Buckley --- Buckley
# B --- Claude Friese-Greene --- Greene
# B --- Elizabeth Hamilton Foy. --- .
# A --- John Hanbury-Williams --- Williams
# B --- Charles V --- V.
# B --- Janelle Corlass-Brown --- Brown
# B --- Charles S --- S.
# B --- Barbara Evadney Reid-Hibbert --- Hibbert
# B --- Mrs --- Mrs.
# B --- Beth Enright/Beresford --- Beresford
# A --- Christopher Trevor-Roberts --- Roberts
# A --- John Heath-Stubbs --- Stubbs
# A --- Carrieri-Russo --- Russo
# B --- Co-Founder --- Founder
# A --- Al-Maqaleh --- Maqaleh
# B --- William of Limburg-Broich --- Broich
# B --- Phyllis --- Phyllis(1975
# B --- half-French --- French
# A --- Sun Yat-Sen --- Sen
# A --- Amanda Winn-Lee --- Lee
# A --- D-BOYS --- BOYS
# A --- Legge-Bourke --- Bourke
# B --- Fanny Blankers-Koen --- Koen
# B --- Ann-Margret --- Margret
# A --- Leveson-Gower --- Gower
# A --- Bauffremont-Courtenay --- Courtenay
# B --- The Fresh Prince of Bel-Air --- Air
# Pronoun --- he --- t)he
# A --- I-Spy --- Spy
# B --- Henry R --- R.
# A --- Ima --- a
# B --- Shakespeare/Bacon --- Bacon
# B --- Sir Eardley-Wilmot --- Wilmot
# B --- Anna Vasilevna Korvin-Kurkovskaya --- Kurkovskaya
# A --- Serena --- Serena-
# A --- Carol Cooling-Kopp --- Kopp
# B --- Holly Hunt Design. --- .
# B --- Patricia Perkins-Auguste --- Auguste
# A --- Leonora Cristobal --- Cristobal(Giovanna
# A --- Hans-Holger --- Holger
# B --- Nancy Thorpe/Garvey --- Garvey
# A --- Olivia Newton-John --- John
# B --- Kane --- Kane-
# B --- Gloria Macapagal-Arroyo --- Arroyo
# A --- Fanny Salvini-Donatelli --- Donatelli
# A --- Rawlings-Blake --- Blake
# A --- Nickson-Soul --- Soul
# B --- Brenda K --- K.
# A --- Byng-Johnson --- Johnson
# B --- Jimmy Jean-Louis --- Louis
# A --- Upton-Brown --- Brown
# A --- Women's Hockey News Second Team All-American --- American
# B --- Stacy X --- X.
# A --- Hi-Tek --- Tek
# B --- Wilma Billones-Dalrymple --- Dalrymple
# A --- Barbara Siggers-Franklin --- Franklin
# B --- William S --- S.
# B --- Shaun Wright-Phillips --- Phillips
# A --- Cullis-Hill --- Hill
# B --- Gloria Peri-Smith --- Smith
# A --- T'Chung Jin May-may --- may
# B --- Jin-qua --- qua
# B --- A-ko --- ko
# A --- Mattek-Sands --- Sands
# B --- Mira Adanja-Polak --- Polak
# B --- Hedwig G-G --- G.
# A --- Mohammed ash-Sheikh --- Sheikh
# B --- Letizia Brichetto-Arnaboldi --- Arnaboldi
# A --- Mary Ann. --- .
# A --- Frederick I, Margrave of Brandenburg-Ansbach --- Ansbach
# B --- Heyward-Bey --- Bey
# B --- Atwater-Rhodes --- Rhodes
# B --- Wilbur D. Owens, Jr. --- ..
# B --- Mrs --- Mrs.
# A --- Anne-Marie --- Marie
# B --- Yvette McCausland-Durie --- Durie
# A --- Zeta-Jones --- Jones
# A --- Chiang Ching-kuo --- kuo
# B --- Daphne Rubin-Vega --- Vega
# B --- Levett-Yeats --- Yeats
# B --- Joan Plumleigh-Bruce --- Bruce
# B --- Chow Yun-fat --- fat
# A --- Lipkin-Shahak --- Shahak
# B --- Deborah Carthy-Deu --- Deu
# B --- Federico II. --- .
# B --- Sr. --- .
# B --- Ronald Farren-Price --- Price
# B --- Former --- Minister(Former
# A --- Silke Maier-Witt --- Witt
# B --- Ramona Trinidad Iglesias-Jordan --- Jordan
# A --- Kilmer-Purcell --- Purcell
# A --- Rangeley-Wilson --- Wilson
# B --- Johnson-George --- George
# A --- Frances Cave-Browne-Cave --- Cave
# B --- Carpenter-McMillan --- McMillan
# A --- D-Napoleon --- Napoleon
# A --- Anne Quast-Welts --- Welts
# B --- Kate Louise-Elliot --- Elliot
# B --- Air Officer Commanding --- Commanding(AOC
# B --- Brooke Howard-Smith --- Smith
# A --- Scott-Young --- Young
# A --- Park Ji-Sung --- Sung
# A --- al-Ahnaf --- Ahnaf
# B --- Vice-Chairperson --- Chairperson
# B --- Inez Chandler-Richter --- Richter
# B --- David D --- D.
# A --- Sr. --- .
# B --- Pryce-Jenkins --- Jenkins
# A --- Walter Angelo Fox-Strangways --- Strangways
# A --- Tamargo-Sanchez --- Sanchez
# B --- Janis Joplin. --- .
# B --- Karen R --- R.
# B --- Hedwig Elizabeth Charlotte of Holstein-Gottorp --- Gottorp
# A --- Yi Tso-lin --- lin
# B --- Co-Host --- Host
# A --- Velez-Mitchell --- Mitchell
# A --- Daisy Peshkov-the --- the
# B --- Bill France, Sr. --- .
# A --- Bernard-Alphonse --- Alphonse
# B --- Ilham al-Madfai --- Madfai
# B --- Chiang Kai-shek --- shek
# B --- Helen Foster-Barham --- Barham
# A --- Baker-Finch --- Finch
# A --- Yoon Yeo-jeong --- jeong
# B --- William J --- J.
# A --- Scott-Arruda --- Arruda
# B --- Na-Mara --- Mara
# A --- May-Treanor --- Treanor
# B --- Cleopatra I --- I.
# A --- Chang Ya-juo --- juo
# A --- Pittsburgh Pirates Hall-of-Famer --- Famer
# B --- Philip K --- K.
# B --- Adelheid of Hohenlohe-Langenburg --- Langenburg
# B --- Grandma Larsen --- Larsen(who
# B --- Johnston Forbes-Robertson --- Robertson
# A --- Hammes-Schiffer --- Schiffer
# A --- Catharina-Amalia --- Amalia
# B --- Princess of Orange-Nassau --- Nassau
# A --- Suzy Favor-Hamilton --- Hamilton
# B --- Xavier Foupa-Pokam --- Pokam
# A --- Morris-Gowdy --- Gowdy
# B --- Kate Miller-Heidke --- Heidke
# B --- Co-Director --- Director
# A --- Diana Furchtgott-Roth --- Roth
# B --- Matthew Whitworth-Aylmer --- Aylmer
# B --- Honeyman-Scott --- Scott
# B --- Terry J. Hatter, Jr. --- ..
# A --- Desiree Armfeldt --- Armfeldt''--is
# A --- Henri Milne-Edwards --- Edwards
# B --- Jean-Gilles --- Gilles
# A --- Lombardo-Radice --- Radice
# A --- Shirley Cleary-Cooper --- Cooper
# A --- Anna of Mecklenburg-Schwerin --- Schwerin
# A --- George W. --- W.F.
# B --- Alicia by writing a B-movie --- movie
# B --- Judah Ben-Hur --- Hur
# A --- Huntington-Whiteley --- Whiteley
# A --- Mahmoud Abdul-Rauf --- Rauf
# A --- Nasser Al-Sabah --- Sabah
# B --- al-Naqib --- Naqib
# B --- Helen Mahon-Stroud --- Stroud
# B --- Loucas von Zabiensky-Mebrouk --- Mebrouk
# B --- Buffy Sainte-Marie --- Marie
# B --- Kumari-Baker --- Baker
# A --- Campbell-Hughes --- Hughes
# B --- Solomon Blatt, Jr. --- ..
# A --- Tuckwell-Smith --- Smith
# A --- Edward II. --- .
# B --- Amelia Margarita Rodriguez-Gonzalez --- Gonzalez
# A --- Abd al-Malik --- Malik
# A --- Hadleigh-West --- West
# B --- al-Assad --- Assad
# B --- William Beckett-Denison --- Denison
# B --- Lorenzo D --- D.
# B --- Williams-Taylor --- Taylor
# B --- Thomas Weld-Blundell --- Blundell
# B --- Lorraine/Ensemble --- Ensemble
# B --- Ruggles-Brise --- Brise
# B --- Yeo-Thomas --- Thomas
# B --- James H. Jarvis II. --- .
# B --- Vicar-General --- General
# B --- Ann Drummond-Grant --- Grant
# A --- Sarah Phillips-McCardle --- McCardle
# B --- Valerie Brisco-Hooks --- Hooks
# B --- Katherine Duncan-Jones --- Jones
# B --- Lady Hay Drummond-Hay --- Hay
# B --- Alice --- Alice(1848
# B --- Janner-Klausner --- Klausner
# A --- Damasus-Aboderin --- Aboderin
# A --- Chavez-Thompson --- Thompson
# A --- William III. --- .
# A --- McLendon-Covey --- Covey
# B --- Co-Director --- Director
# Pronoun --- him --- him:``'Stuey
# A --- Catherine Anne Chichester-Cooke --- Cooke
# A --- Huang Chien-Liang --- Liang
# B --- Dame Julie Andrews --- Andrews(under
# B --- Cindy Bortz-Gould --- Gould
# A --- Bradley Chedester Cabaness-Soileau --- Soileau
# B --- Louis Cottrell, Sr. --- .
# B --- Novoselki-Kudrino --- Kudrino
# B --- Kumari-Baker --- Baker
# B --- Sr. --- .
# A --- Nellie Miller-Mann --- Mann
# B --- William H --- H.
# B --- K.C. --- K.C.H.
# A --- Rubin-Vega --- Vega
# A --- Park Shin-yang --- yang
# B --- Clare Bange-Hall --- Hall
# B --- Chan Wah-shun --- shun
# B --- Stephen S. Chandler, Jr. --- ..
# B --- Young-Bruehl --- Bruehl
# A --- Anouk Leblanc-Boucher --- Boucher
# B --- K-Dot --- Dot
# A --- Evan-Thomas --- Thomas
# B --- Ishaq al-Jundi --- Jundi
# B --- Margrave of Brandenburg-Ansbach --- Ansbach
# A --- Silvia Bulfone-Paus --- Paus
# B --- Anglo-Catholic --- Catholic
# B --- Carina II. --- .
# A --- Dominique Strauss-Kahn --- Kahn
# A --- Ioana Petcu-Colan --- Colan
# B --- Ruxandra Colan-Petcu --- Petcu
# B --- Loch-Wilkinson --- Wilkinson
# A --- Harold Alfred ``Tex'' Hinte Sr. --- .
# B --- Felicia Scorpio-Jones --- Jones
# B --- Sir Eustace Sulyard. --- .
# A --- Bartlett-O'Reilly --- O'Reilly
# A --- Mae/Linda --- Linda
# B --- Kecia Pratt-McCullar --- McCullar
# B --- Jackson Democratic-Republican --- Republican
# B --- Timm-Rudolph --- Rudolph
# A --- Liao Feng-teh --- teh
# B --- Charlotte Townsend-Gault --- Gault
# B --- D --- D.
# B --- Elizabeth A --- A.
# B --- Olivia Newton-John --- John
# A --- Avril de Sainte-Croix --- Croix
# B --- Rev --- Rev.
# B --- St-Pierre --- Pierre
# B --- Catherine Zeta-Jones --- Jones
# A --- Bill Scott-Kerr --- Kerr
# B --- Franklin D --- D.
# A --- Frederick Hamilton-Temple-Blackwood --- Blackwood
# A --- Ana Andi Lezzi --- Lezzi'',''Zourou
# B --- Shari Leibbrandt-Demmon --- Demmon
# A --- Jennifer Ward-Lealand --- Lealand
# A --- Humphreys-Owen --- Owen
# A --- Marion-Crawford --- Crawford
# B --- Vita Sackville-West --- West
# A --- John-Lewis --- Lewis
# A --- Baillie-Hamilton --- Hamilton
# B --- Owen Owen Ltd --- Ltd.
# A --- Bromley-Davenport --- Davenport
# A --- Edmund Phipps-Hornby --- Hornby
# B --- Christina Park. --- .
# B --- Carol Neiman-Margolin --- Margolin
# A --- Robert Downey Sr. --- .
# B --- Carrie Jacobs-Bond --- Bond
# B --- Dan Monroe Russell, Jr. --- ..
# B --- Robert Patton-Spruill --- Spruill
# A --- Miep den Oude-Snel --- Snel
# A --- Kim-Lian --- Lian
# A --- Anne-Marie --- Marie
# B --- Kojo Boakye-Djan --- Djan
# A --- Sophia Jex-Blake --- Blake
# [5, 37, 96, 155, 159, 188, 207, 227, 266, 457, 515, 534, 616, 634, 675, 702, 881, 1048, 1077, 1128, 1164, 1183, 1203, 1246, 1312, 1338, 1371, 1374, 1409, 1460, 1514, 1566, 1573, 1607, 1648, 1772, 1826, 1909, 1932, 1988, 2002, 2050, 2052, 2054, 2081, 2136, 2141, 2252, 2265, 2269, 2317, 2359, 2518, 2520, 2540, 2577, 2628, 2636, 2707, 2776, 2837, 2864, 2870, 2982, 3050, 3050, 3094, 3129, 3134, 3148, 3169, 3199, 3218, 3241, 3254, 3290, 3324, 3405, 3425, 3436, 3481, 3510, 3541, 3548, 3596, 3627, 3707, 3720, 3804, 3829, 3859, 4060, 4067, 4125, 4216, 4265, 4337, 4375, 4442, 4490, 4529, 4672, 4768, 4786, 4796, 4828, 4849, 4856, 4898, 4942, 4968, 4999, 5030, 5061, 5092, 5199, 5267, 5275, 5382, 5394, 5428, 5452, 5525, 5563, 5576, 5613, 5670, 5677, 5729, 5763, 5784, 5815, 5907, 5945, 5961, 5967, 6074, 6118, 6211, 6222, 6225, 6225, 6339, 6389, 6419, 6435, 6576, 6705, 6746, 6817, 6824, 7217, 7279, 7353, 7381, 7398, 7437, 7458, 7541, 7589, 7652, 7716, 7746, 7746, 7765, 7801, 7926, 7936, 7977, 8028, 8032, 8046, 8106, 8271, 8327, 8368, 8378, 8475, 8477, 8594, 8602, 8700, 8737, 8751, 8762, 8781, 8783, 8878, 8944, 8964, 8969, 8975, 8992, 9075, 9108, 9250, 9260, 9302, 9304, 9359, 9446, 9563, 9569, 9620, 9903, 9960, 10014, 10021, 10029, 10041, 10058, 10101, 10132, 10144, 10301, 10355, 10397, 10432, 10471, 10574, 10614, 10622, 10667, 10673, 10713, 10718, 10718, 10765, 10813, 10827, 10843, 10847, 10915, 10943, 10962, 10965, 11009, 11032, 11109, 11155, 11166, 11205, 11253, 11274, 11285, 11337, 11353, 11356, 11380, 11381, 11603, 11616, 11676, 11686, 11733, 11735, 11796, 11869, 11885, 11917, 12110, 12144, 12145, 12166, 12219, 12233, 12259, 12283, 12315, 12322]

# %%
gendered_pronoun_df.columns
# Out:
# Index(['ID', 'Text', 'Pronoun', 'Pronoun-offset', 'A', 'A-offset', 'A-coref',
#        'B', 'B-offset', 'B-coref', 'URL', 'doc', 'Pronoun-index',
#        'Pronoun-sent', 'Pronoun-depth', 'Pronoun-ancestor', 'Pronoun-dep',
#        'A-index', 'A-sent', 'A-depth', 'A-ancestor', 'A-dep', 'A-sentdistance',
#        'A-depthdistance', 'A-sameancestor', 'A-samedep', 'B-index', 'B-sent',
#        'B-depth', 'B-ancestor', 'B-dep', 'B-sentdistance', 'B-depthdistance',
#        'B-sameancestor', 'B-samedep'],
#       dtype='object')

# %%
X = gendered_pronoun_df[['A-dep', 'B-dep','Pronoun-dep', 
                        'A-sentdistance', 'A-depthdistance', 'A-sameancestor','A-samedep',
                        'B-sentdistance', 'B-depthdistance', 'B-sameancestor','B-samedep']]

# %%
test_X = test_df2[['A-dep', 'B-dep','Pronoun-dep', 
                        'A-sentdistance', 'A-depthdistance', 'A-sameancestor','A-samedep',
                        'B-sentdistance', 'B-depthdistance', 'B-sameancestor','B-samedep']]

# %%
joined_X = pd.concat([X,test_X])

# %%
one_hot_encoded_joined_X = pd.get_dummies(joined_X)
print(one_hot_encoded_joined_X.shape)
# Out:
# (14359, 82)

# %%
one_hot_encoded_X = one_hot_encoded_joined_X.iloc[:2000]
one_hot_encoded_test_X = one_hot_encoded_joined_X.iloc[2000:]

# %%
def consistant(df):
    Ylabel=[]
    for row_index,row in df.iterrows():
        if row['A-coref']==True:
            Ylabel.append(0)
        elif row['B-coref']==True:
            Ylabel.append(1)
        else:
            Ylabel.append(2)
    return Ylabel

# %%
Y = np.array(consistant(gendered_pronoun_df))

# %%
Y.shape
# Out:
# (2000,)

# %%
#Xtrain,XCV,Ytrain,YCV = one_hot_encoded_X[:1500],one_hot_encoded_X[1500:],Y[:1500],Y[1500:]

# %%
from sklearn.metrics import accuracy_score
from sklearn import *
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
n_splits = 5
splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=2019).split(one_hot_encoded_X, np.zeros(shape=(one_hot_encoded_X.shape[0], 1))))

# %%
params = {
          "objective" : "multiclass",
          "num_class" : 3,
          "num_leaves" : 30,
          "max_depth": -1,
          "learning_rate" : 0.01,
          "bagging_fraction" : 0.6,  # subsample
          "feature_fraction" : 0.6,  # colsample_bytree
          "bagging_freq" : 5,        # subsample_freq
          "bagging_seed" : 2018,
          "verbosity" : -1 }

preds_test = []

for idx, (train_idx, val_idx) in enumerate(splits):
    
    print("Beginning fold {}".format(idx+1))
    Xtrain, Ytrain, XCV, YCV = one_hot_encoded_X.iloc[train_idx], Y[train_idx], one_hot_encoded_X.iloc[val_idx], Y[val_idx]
    lgtrain, lgval = lgb.Dataset(Xtrain,Ytrain), lgb.Dataset(XCV,YCV)
    lgbmodel = lgb.train(params, lgtrain, 2000, valid_sets=[lgtrain, lgval], early_stopping_rounds=100, verbose_eval=200)
    pred=lgbmodel.predict(one_hot_encoded_test_X)
    preds_test.append(pred)

preds_test = np.mean(preds_test, axis=0)
print(preds_test.shape)
# Out:
# Beginning fold 1
# Training until validation scores don't improve for 100 rounds.
# [200]	training's multi_logloss: 0.655315	valid_1's multi_logloss: 0.72929
# [400]	training's multi_logloss: 0.572688	valid_1's multi_logloss: 0.709235
# Early stopping, best iteration is:
# [420]	training's multi_logloss: 0.566856	valid_1's multi_logloss: 0.708087
# Beginning fold 2
# Training until validation scores don't improve for 100 rounds.
# [200]	training's multi_logloss: 0.658598	valid_1's multi_logloss: 0.724297
# [400]	training's multi_logloss: 0.574542	valid_1's multi_logloss: 0.699338
# Early stopping, best iteration is:
# [425]	training's multi_logloss: 0.566951	valid_1's multi_logloss: 0.698119
# Beginning fold 3
# Training until validation scores don't improve for 100 rounds.
# [200]	training's multi_logloss: 0.671255	valid_1's multi_logloss: 0.692448
# [400]	training's multi_logloss: 0.589698	valid_1's multi_logloss: 0.654475
# [600]	training's multi_logloss: 0.540126	valid_1's multi_logloss: 0.649287
# Early stopping, best iteration is:
# [532]	training's multi_logloss: 0.555132	valid_1's multi_logloss: 0.647927
# Beginning fold 4
# Training until validation scores don't improve for 100 rounds.
# [200]	training's multi_logloss: 0.65199	valid_1's multi_logloss: 0.75797
# [400]	training's multi_logloss: 0.569445	valid_1's multi_logloss: 0.738462
# Early stopping, best iteration is:
# [375]	training's multi_logloss: 0.57727	valid_1's multi_logloss: 0.737607
# Beginning fold 5
# Training until validation scores don't improve for 100 rounds.
# [200]	training's multi_logloss: 0.660752	valid_1's multi_logloss: 0.735533
# [400]	training's multi_logloss: 0.578323	valid_1's multi_logloss: 0.706851
# Early stopping, best iteration is:
# [412]	training's multi_logloss: 0.57447	valid_1's multi_logloss: 0.706359
# (12359, 3)

# %%
preds_test[:10]
# Out:
# array([[0.84079579, 0.0970818 , 0.06212241],
#        [0.87275508, 0.0870051 , 0.04023983],
#        [0.12003613, 0.85912486, 0.02083901],
#        [0.85418223, 0.0985016 , 0.04731617],
#        [0.33897014, 0.60831916, 0.0527107 ],
#        [0.93397192, 0.03657491, 0.02945317],
#        [0.55842207, 0.41638526, 0.02519267],
#        [0.02891246, 0.94789833, 0.02318921],
#        [0.52569098, 0.45406974, 0.02023928],
#        [0.1312903 , 0.39345758, 0.47525212]])

# %%
submission2.head()
# Out:
#                                  ID        A        B  NEITHER
# 0  000075809a8e6b062f5fb3c191a8ed52  0.33333  0.33333  0.33333
# 1  0005d0f3b0a6c9ffbd31a48453029911  0.33333  0.33333  0.33333
# 2  0007775c40bedd4147a0573d66dc28f8  0.33333  0.33333  0.33333
# 3  001194e3fe1234d00198ef6bba4cc588  0.33333  0.33333  0.33333
# 4  0014bb7085278ef3f9b74f14771caca9  0.33333  0.33333  0.33333

# %%
submission2[['A','B','NEITHER']] = preds_test

# %%
submission2.head()
# Out:
#                                  ID         A         B   NEITHER
# 0  000075809a8e6b062f5fb3c191a8ed52  0.840796  0.097082  0.062122
# 1  0005d0f3b0a6c9ffbd31a48453029911  0.872755  0.087005  0.040240
# 2  0007775c40bedd4147a0573d66dc28f8  0.120036  0.859125  0.020839
# 3  001194e3fe1234d00198ef6bba4cc588  0.854182  0.098502  0.047316
# 4  0014bb7085278ef3f9b74f14771caca9  0.338970  0.608319  0.052711

# %%
submission2.to_csv('submission2.csv', index=False)
